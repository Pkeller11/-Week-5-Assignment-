# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd

# %matplotlib inline
sns.set()

# %%
import os
 
def current_path():
    print("Current working directory before")
    print(os.getcwd())
    print()
 
current_path()

os.chdir('/Users/paige/Downloads')
current_path()
# Out:
# Current working directory before
# /Users/paige
#
# Current working directory before
# /Users/paige/Downloads

# %%
df = pd.read_csv('winequality-red.csv', index_col = 'quality')
df
# Out:
#          fixed acidity  volatile acidity  citric acid  residual sugar  \
# quality
# 5                  7.4             0.700         0.00             1.9
# 5                  7.8             0.880         0.00             2.6
# 5                  7.8             0.760         0.04             2.3
# 6                 11.2             0.280         0.56             1.9
# 5                  7.4             0.700         0.00             1.9
# ...                ...               ...          ...             ...
# 5                  6.2             0.600         0.08             2.0
# 6                  5.9             0.550         0.10             2.2
# 6                  6.3             0.510         0.13             2.3
# 5                  5.9             0.645         0.12             2.0
# 6                  6.0             0.310         0.47             3.6
#
#          chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# quality
# ...

# %%
df.plot.scatter(3,4, c='darkorchid')
plt.title('Chlorides vs Residual Sugar')
# Out:
# Text(0.5, 1.0, 'Chlorides vs Residual Sugar')

# %%
corrmat = df.corr()
f, ax = plt.subplots(figsize=(12,10))
sns.heatmap(corrmat, vmax = .8, square=True)
plt.title('Wine Quality by Input Variables')
# Out:
# Text(0.5, 1.0, 'Wine Quality by Input Variables')

# %%
sns.displot(df['pH'],kde=True)
plt.title('Wine pH Levels')
# Out:
# Text(0.5, 1.0, 'Wine pH Levels')
